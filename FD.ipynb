# %%
from main import Experiment

# %%
experiment = Experiment("DANN", "FD")
experiment.main(plot=True)
# Out:
#          CWRU_FE   CWRU_DE
# CWRU_FE      1.0  0.589286
#           CWRU_FE   CWRU_DE
# CWRU_FE  1.000000  0.589286
# CWRU_DE  0.761905  0.626488
#           CWRU_FE   CWRU_DE       ACC       BWT  Adaptability
# CWRU_FE  1.000000  0.589286  1.000000  0.000000      0.000000
# CWRU_DE  0.761905  0.626488  0.694196 -0.238095      0.037202
#          CWRU_DE   CWRU_FE
# CWRU_DE      1.0  0.459821
#           CWRU_DE   CWRU_FE
# CWRU_DE  1.000000  0.459821
# CWRU_FE  0.645833  0.700893
#           CWRU_DE   CWRU_FE       ACC       BWT  Adaptability
# CWRU_DE  1.000000  0.459821  1.000000  0.000000      0.000000
# CWRU_FE  0.645833  0.700893  0.673363 -0.354167      0.241071
#                PB_Artificial   PB_Real
# PB_Artificial       0.993473  0.609905
#                PB_Artificial   PB_Real
# PB_Artificial       0.993473  0.609905
# PB_Real             0.939377  0.550669
#                PB_Artificial   PB_Real       ACC       BWT  Adaptability
# ...
