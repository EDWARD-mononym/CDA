# %%
from main import Experiment

# %%
experiment = Experiment("DANN", "FD")
experiment.main(plot=True)
# Out:
#          CWRU_DE   CWRU_FE
# CWRU_DE      1.0  0.620536
#           CWRU_DE   CWRU_FE
# CWRU_DE  1.000000  0.620536
# CWRU_FE  0.998512  0.422619
#           CWRU_DE   CWRU_FE       ACC       BWT  Adaptability
# CWRU_DE  1.000000  0.620536  1.000000  0.000000      0.000000
# CWRU_FE  0.998512  0.422619  0.710565 -0.001488     -0.197917
#          CWRU_FE   CWRU_DE
# CWRU_FE      1.0  0.886905
#           CWRU_FE   CWRU_DE
# CWRU_FE  1.000000  0.886905
# CWRU_DE  0.998512  0.994048
#           CWRU_FE   CWRU_DE      ACC       BWT  Adaptability
# CWRU_FE  1.000000  0.886905  1.00000  0.000000      0.000000
# CWRU_DE  0.998512  0.994048  0.99628 -0.001488      0.107143
#                PB_Artificial   PB_Real
# PB_Artificial       0.981071  0.626061
#                PB_Artificial   PB_Real
# PB_Artificial       0.981071  0.626061
# PB_Real             0.959204  0.641074
#                PB_Artificial   PB_Real       ACC       BWT  Adaptability
# ...
