# %%
from main import Experiment

# %%
experiment = Experiment("DANN", "HHAR")
experiment.main(plot=True)
# Out:
#           8         7         2         1         3       ACC       BWT  \
# 8  1.000000  0.682460  0.264815  0.852328  0.781944  1.000000  0.000000
# 7  1.000000  0.899798  0.350617  0.694240  0.925926  0.949899  0.000000
# 2  0.996324  0.885148  0.487963  0.774510  0.892593  0.789811 -0.009163
# 1  0.996324  0.935349  0.372222  0.966912  0.950926  0.817702 -0.027955
# 3  1.000000  0.927016  0.393441  0.958946  0.959259  0.847733 -0.018817
#
#    Adaptability
# 8      0.000000
# 7      0.217339
# 2      0.177342
# 1      0.182362
# 3      0.138855
#           0         2         1         3         4       ACC       BWT  \
# 0  0.985417  0.621914  0.416667  0.459954  0.512091  0.985417  0.000000
# 2  0.985417  0.812654  0.451593  0.465972  0.434896  0.899035  0.000000
# 1  0.981250  0.709414  0.754289  0.647454  0.647042  0.814984 -0.053704
# 3  0.979167  0.709414  0.746936  0.742361  0.680246  0.794469 -0.038948
# ...
