# %%
from main import Experiment

# %%
experiment = Experiment("DANN", "CWRU")
experiment.main(plot = True)
# Out:
#       DE_7      FE_7
# DE_7   1.0  0.479167
#           DE_7      FE_7
# DE_7  1.000000  0.479167
# FE_7  0.945312  1.000000
#           DE_7      FE_7       ACC       BWT  Adaptability
# DE_7  1.000000  0.479167  1.000000  0.000000      0.000000
# FE_7  0.945312  1.000000  0.972656 -0.054688      0.520833
#       DE_7     FE_14
# DE_7   1.0  0.471354
#            DE_7     FE_14
# DE_7   1.000000  0.471354
# FE_14  0.502604  0.520833
#            DE_7     FE_14       ACC       BWT  Adaptability
# DE_7   1.000000  0.471354  1.000000  0.000000      0.000000
# FE_14  0.502604  0.520833  0.511719 -0.497396      0.049479
#       DE_7     FE_21
# DE_7   1.0  0.479167
#            DE_7     FE_21
# DE_7   1.000000  0.479167
# FE_21  0.763021  0.458333
#            DE_7     FE_21       ACC       BWT  Adaptability
# DE_7   1.000000  0.479167  1.000000  0.000000      0.000000
# FE_21  0.763021  0.458333  0.610677 -0.236979     -0.020833
#       FE_7      DE_7
# FE_7   1.0  0.760417
# ...
